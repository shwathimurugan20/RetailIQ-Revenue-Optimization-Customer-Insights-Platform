# %%
# !pip install sqlalchemy pymysql

# %%
import pandas as pd

customers = pd.read_csv("customers_clean.csv")
orders = pd.read_csv("orders_clean.csv")
products = pd.read_csv("products_clean.csv")
order_items = pd.read_csv("order_items_clean.csv")
payments = pd.read_csv("payments_clean.csv")

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("Saradha@1704")

engine = create_engine(f"mysql+pymysql://root:{password}@localhost/nykaa_project")

# %%
customers.to_sql("customers", engine, if_exists='replace', index=False)
products.to_sql("products", engine, if_exists='replace', index=False)
orders.to_sql("orders", engine, if_exists='replace', index=False)
order_items.to_sql("order_items", engine, if_exists='replace', index=False)
payments.to_sql("payments", engine, if_exists='replace', index=False)
# Out:
# 10000
